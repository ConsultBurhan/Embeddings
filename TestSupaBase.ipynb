# %% [markdown]
# ## ToDo's
# 1. Check the supabase bucket system works and be able to get the URL out of it (done)
# 2. Create the embedding system using the opensource model that we discussed
# 3. Create the Qdrant function for uploading the embedding and retriving the embeddings
# 4. create a simple langchain agent to check if it works
# 5. create a simple function to take the file as input
# 6. create the ingestfile function which uploads the file to the supabase
# 7. append the functionality of extracting the embeddings from the image and upload it to the Qdrant and the image to supabase
# 8. be able to retreive the image and the text as well.
